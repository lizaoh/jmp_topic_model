# %%
import subprocess

p = subprocess.Popen(
    "topicexplorer notebook config.ini",
    stdin=subprocess.PIPE,
    shell=True,
    text=True
)

p.communicate("n\nn")  # answers "n" to overwriting corpus.py and notebook
